# %% [markdown]
# ### <u> Understand: First Step to an Effective Chart</u>
#
# __Instructions :__
# 1. Find 2 charts you like and 2 you don't like, identify a few top attributes that you lead you to like or not like the chart.
#
# 2. Find 2 clear charts and 2 muddled charts. What are the attributes that lead to the clarity or lack of clarity?
#
# 3. Find 2 charts that deceive. What technique(s) are used to deceive?
#
# 4. Select 3 charts to evaluate then walk through the critiquing process for each.

# %% [markdown]
# __Systematically critique charts__
#
# 1. Note the first few things you see
# 2. What is the first idea that forms in your mind? Note it and then search for more.
# 3. What is the idea being conveyed?
# 4. Does it match the chart's seeming intent?
# 5. Is there anything misleading in the chart?
# 6. Is something missing?
# 7. Note likes, dislikes, wish-I-saws
# 8. Find 3 things you would change...note them and explain why
# 9. Sketch and/or protoype your own version and critically evaluate yours.

# %% [markdown]
# 1. Find 2 charts you like, identify a few top attributes that you lead you to like or not like the chart.
#
# __Liked__
# ![leo_decaprio.png](attachment:leo_decaprio.png)
#
# <u>Attributes I Like</u>:
# * The chart is very througrough in its attempt to convey a grat deal of data all in one chart.
# * Typically all this data would have to be broken down into a few charts of different types I feel, however the layout of the chart keeeps it very readable.

# %% [markdown]
# __Liked__
# ![trump_vs_biden.png](attachment:trump_vs_biden.png)
#
# <u>Attributes I Like</u>:
# * Very simple yet fascinating visualization that puts the actual topic into a perspective I had never thought about or read into myself.
# * I like how the chart labled the presidential nominees with easy to decipher photoss, rather than attemting to label them using just the dots.

# %% [markdown]
# 2. Find 2 you don't like, identify a few top attributes that you lead you to like or not like the chart.
# __Did Not Like__
#
# ![bd_graph.jpg](attachment:bd_graph.jpg)
#
# <u>Attributes I Don't Like</u>:
# * This chart is confusing on so many levels. Firstly, I have no idea what the unit of measurement is. I also have no idea where to start, and cant seem to get a feel for where there intended presenter would want me to direct my attention.
# * The color combinations don't work for me either, the darkblue maked the black numbers more confusing to try and sort through making it an almost unreadable chart.

# %% [markdown]
# __Did Not Like__
# ![bad_shows.png](attachment:bad_shows.png)
#
# <u>Attributes I Don't Like</u>:
# * Good concept in theory however I believe they attempted to include too many data sets in one chart. Makes it seem bloated and therefore hard to follow.
# * I had a hard time the color scheme since the legend was blank,and with that much going on the chart, a different approach seems necessary because it gets a bit tasking trying to keep up with it all.

# %% [markdown]
# 2. Find 2 clear charts and 2 muddled charts. What are the attributes that lead to the clarity or lack of clarity?
#
# __Clear__
# ![beyond_meat_vs_beef_patty.png](attachment:beyond_meat_vs_beef_patty.png)
#
# * I was able to qucikly decipher the chart, thanks to the colors used, as well as the minimalistic approach.
# * I immediately see and feel as if I understand the comparison the chart is making and it definately peaked my intrest.

# %% [markdown]
# ![google_trends.png](attachment:google_trends.png)
#
# * Although there is a lot of data to follow on the chart, it feels very readable, the colors seem to complement the chart type pretty well.
# * There are very concise references throughout the chart, making it easy to get back on track if you lose your way at any point reading through.

# %% [markdown]
# __Muddled__
#
# ![congress_stats.png](attachment:congress_stats.png)
# * I'm not sure if I'm supposed to count the percentages in my head or if the chart felt it unneccessary, so I don't feel the pecieved intended impact.
# * The "US Population" aspect of the chart makes me suspiscious as to the where the source of all this data came from, there is none noted, and therefore that brings down the validity of the entire chart for me.

# %% [markdown]
# __Muddled__
